# %%
import pandas as pd

# %% [markdown]
# ## Desafio 1 - Importação de arquivo CSV
#
# Será necessário fazer a leitura desse arquivo CSV, porém ele apresenta alguns padrões diferentes que devem ser tratados.
#
# **Importante: analise cuidadosamente o arquivo a cada etapa para entender o que falta.**

# %%
path_dados_sus = 'in/dados_sus.csv'

# %%
try:
    pd.read_csv('in/dados_sus.csv')
except UnicodeDecodeError as e:
    print(e)
# Out:
# 'utf-8' codec can't decode byte 0xe7 in position 56: invalid continuation byte

# %% [markdown]
# Primeiramente, o encoder do arquivo é diferente, usaremos a lib `chardet` para esse trabalho.

# %%
from chardet import detect

def get_file_encoding():
    with open(path_dados_sus, 'rb') as file:
        return detect(file.read())['encoding']

encoding = get_file_encoding()

# %%
dados_sus = pd.read_csv('in/dados_sus.csv', encoding=encoding, skiprows=5, sep=';', skipfooter=10, engine='python')
dados_sus.head()
# Out:
#         Acre    902416,00   1497206,26   1794028,48   1730469,42   1819443,92  \
# 0   Amazonas   4735529,42   7118990,57   8196635,49   8259378,42   7831399,90
# 1    Roraima    657889,53    777939,31    718688,03    839994,39    862347,96
# 2       Pará  18864744,11  19553758,20  21937342,70  20842829,69  23249952,88
# 3      Amapá   1120973,34   1268740,33    974651,24   1141137,32    866346,18
# 4  Tocantins   3441592,69   4985688,85   6205612,60   4984482,09   5511002,46
#
#     1828496,00   2511754,59   2089107,14   2275708,53  ...   3915193,20  \
# 0   8477273,62   9368858,72   9352532,70   9363099,35  ...  19769460,14
# 1    832440,66    996693,09    894271,18    910424,17  ...   3015488,30
# 2  23240687,56  24002223,56  23341218,03  25172261,32  ...  40804126,43
# 3   1440978,95   1426659,48   1475551,38   1651341,43  ...   3253399,45
# 4   4927934,22   5445602,28   5413710,38   5596669,50  ...   9155572,36
#
#     3640142,82   3391242,21   4044321,44   3276590,10   3696997,31  \
# 0  18059931,43  17841015,63  16408315,10  19895617,91  17765167,69
# 1   2826486,18   2928043,91   3090313,73   3621031,05   3454460,94
# 2  44385715,88  36820249,47  36965931,34  39004315,80  38015145,79
# 3   2946398,44   2416019,23   2203732,04   2218532,26   2566919,60
# 4   8390267,72   8729632,49   7770885,66    527840,46    675277,05
#
#     3715723,12   3538427,92   4077045,92   450048530,47
# 0  21430289,17  25917134,55  22032176,22  1917247936,05
# 1   3266928,47   3519773,73   3985530,08   328876965,09
# 2  38354682,46  37688314,23  33276392,89  4705309002,29
# 3   2802886,34   2817849,31   3188210,98   309860092,59
# 4    419553,49    319160,87   1357751,33  1020028272,64
#
# [5 rows x 161 columns]

# %% [markdown]
# ### Explicação:
#
# * `encoding='ISO-8859-1'`: tipo de codificação dos caracteres do arquivo. Neste caso, é a codificação ISO-8859-1 que é comum em arquivos de língua portuguesa.
# * `sep=';'`: separador dos valores no arquivo. Neste caso, é o ponto-e-vírgula (;).
# * `skiprows=3`: indica que as três primeiras linhas do arquivo devem ser ignoradas, pois não contêm dados relevantes.
# * `skipfooter = 10`: indica que as dez últimas linhas do arquivo devem ser ignoradas, pois não contêm dados relevantes.
# * `engine='python'`: o motor usado para ler o arquivo é o Python. Isso é necessário quando se usa o parâmetro skipfooter, pois o motor padrão não suporta essa opção.

# %% [markdown]
# ## Desafio 2 - Leitura de Google Sheets
#
# Com base na url [dessa planilha](https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?gid=1214654498#gid=1214654498) faça a leitura dos dados para o Pandas.

# %%
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

CO2_emission = pd.read_csv(url)
CO2_emission.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# 2  543.557.223     70.898.423    836.804.405    912.141.485  ...
# 3  683.699.826    638.307.036    645.355.189    605.436.253  ...
# 4   69.630.787  6.724.177.518  6.541.578.914  6.733.479.486  ...
#
#             2011           2012           2013           2014           2015  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1     29.650.624    259.295.334     18.562.366    146.235.617    172.896.741
# 2    985.522.312    950.695.879  1.036.293.852  1.099.779.111    113.504.405
# 3    166.942.319    150.324.046  1.533.630.039  1.668.337.371    160.377.515
# 4  5.850.886.105  5.944.654.173  5.942.800.412  5.807.127.723  6.026.181.822
#
#             2016           2017           2018           2019         2019.1
# 0            NaN            NaN            NaN            NaN            NaN
# 1    149.789.334    131.694.556      1.632.953    159.824.372    159.824.372
# 2  1.031.811.348     81.330.073    777.674.934    792.137.069    792.137.069
# 3  1.557.664.358  1.788.786.074  1.782.738.948    169.224.832    169.224.832
# 4  6.080.600.282  6.104.133.912  6.362.975.399  6.481.217.432  6.481.217.432
#
# [5 rows x 35 columns]

# %% [markdown]
# # Desafio 3 - Normalizar Dados de uma API
#
# Capture os dados de uma API pública e normalize sua estrutura (uma das propriedades tem dados aninhados).

# %%
import requests
import json

dados_frutas = requests.get('https://fruityvice.com/api/fruit/all')
resultado = json.loads(dados_frutas.text)

pd.DataFrame(resultado).head()
# Out:
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...

# %%
fruits = pd.json_normalize(resultado)
fruits.head()
# Out:
#          name  id      family         order      genus  nutritions.calories  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros                   81
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria                   29
# 2      Banana   1    Musaceae  Zingiberales       Musa                   96
# 3      Tomato   5  Solanaceae     Solanales    Solanum                   74
# 4        Pear   4    Rosaceae       Rosales      Pyrus                   57
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 0             0.0              18.0                      18.0
# 1             0.4               5.4                       5.5
# 2             0.2              17.2                      22.0
# 3             0.2               2.6                       3.9
# 4             0.1              10.0                      15.0
#
#    nutritions.protein
# 0                 0.0
# 1                 0.8
# 2                 1.0
# 3                 0.9
# 4                 0.4

# %% [markdown]
# # Desafio 4 - Consumir Dados de uma Página Web
#
# Faça a leitura dessa página web de [países por população](https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o) e crie um DataFrame com a tabela de população por país.

# %%
populacao_paises = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')[0]
populacao_paises.head()
# Out:
#    Unnamed: 0 Posição País (ou território dependente) Estimativa da ONU  \
# 0         NaN       1                           Índia     1 429 921 746
# 1         NaN       2                           China     1 426 391 281
# 2         NaN       3                  Estados Unidos       339 987 103
# 3         NaN       4                       Indonésia       277 184 719
# 4         NaN       5                       Paquistão       240 215 932
#
#   Crescimento desde a última estimativa  Estimativa Oficial
# 0                          +269.108.746  Estimativa oficial
# 1                           +87.778.313       Censo oficial
# 2                           +31.241.565       Censo oficial
# 3                           +33.168.546  Estimativa oficial
# 4                           +65.636.932  Estimativa oficial
